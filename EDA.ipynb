# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =sns.load_dataset("iris")
print(df.head())
print(df.tail())
print(df.tail(10))
print(df.head(12))
print(df.shape)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# (150, 5)

# %%
print(df.shape)
print("column",df.columns.tolist())
# Out:
# (150, 5)
# column ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("iris")
print(df.head(10))
print(df.tail())
print(df.shape)
print("columns",df.columns.tolist())
df.info()
print(df.isnull().sum())
print("total missing values",df.isnull().sum().sum())
print("number of rows:",len(df))
print("number of columns:",df.shape[1])
print(df["species"].value_counts())
print(df["species"].value_counts(normalize=True)*100)
print("species:",df["species"].unique())
print(df.select_dtypes("number").mean())
print(df.select_dtypes("number").median())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
# (150, 5)
# columns ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
# total missing values 0
# number of rows: 150
# number of columns: 5
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
# species
# setosa        33.333333
# versicolor    33.333333
# virginica     33.333333
# Name: proportion, dtype: float64
# species: ['setosa' 'versicolor' 'virginica']
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
sns.countplot(data=df, x="species")
plt.title("number of flower in species")
plt.xlabel("species")
plt.ylabel("count")
plt.show()

# %%
sns.histplot(
    data=df,
    x="sepal_length",
    bins=10,
    kde=True
)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.boxplot(
    data=df,
    x="species",
    y="petal_length"
)
plt.title("petal_length by species")
plt.xlabel("species")
plt.ylabel("petal_length")
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import statsmodels.formula.api as smf

# %%
df.hist(figsize=(12,10))
plt.suptitle("Feature Distribution")
plt.show()

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
df = pd.read_csv(url)


plt.scatter(df['rm'], df['medv'])
plt.xlabel("Average Rooms (RM)")
plt.ylabel("House Price (MEDV)")
plt.title("SLR: RM vs MEDV")
plt.show()

# %%
plt.boxplot(df['medv'])
plt.title("Boxplot of House Prices")
plt.show()

# %%
plt.scatter(df['rm'], df['medv'])
plt.xlabel("Average Rooms (RM)")
plt.ylabel("House Price (MEDV)")
plt.title("SLR: RM vs MEDV")
plt.show()

# %%
plt.figure(figsize=(10,8))
corr=df.corr()
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
X_slr=df[['rm']]
y=df['medv']

# %%
X_train,X_test,y_train,y_test=train_test_split(X_slr,y,test_size=0.3,random_state=565)
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(X_slr, y, test_size=0.3, random_state=565)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 1), (152, 1), (354,), (152,))

# %%
X_slr = df[['rm']]
y = df['medv']

# %%
slr = LinearRegression()
slr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_train, X_test, y_train, y_test = train_test_split(X_slr, y, test_size=0.3, random_state=565)
X_train.shape, X_test.shape, y_train.shape, y_test.shape

X_slr = df[['rm']]
y = df['medv']

slr = LinearRegression()
slr.fit(X_train, y_train)

y_pred_slr = slr.predict(X_test)
y_pred_slr

print("\nSLR Results")
print("\nSLR Results")
print("R2:", r2_score(y_test, y_pred_slr))

plt.scatter(X_test, y_test, label="Actual")
plt.plot(X_test, y_pred_slr, color='red', label="Predicted Line")
plt.title("SLR Fit: RM vs MEDV")
plt.legend()
plt.show()
# Out:
# SLR Results
#
# SLR Results
# R2: 0.5525286822355802
# array([19.54976259, 18.31258722, 19.15813873, 41.20478186, 23.77752015,
#        16.65708636, 21.55238459, 24.63197221, 23.60840985, 21.50788188,
#        25.45972264, 21.1963629 , 17.4670357 , 27.40004084, 19.63876801,
#        30.16810948, 19.14033765, -1.64242849, 17.24452215, 19.78117669,
#         8.0680631 , 17.94766499, 13.58639929, 30.5508328 , 21.40997592,
#        17.92096336, 16.78169395, 20.98274989, 17.67174818, 27.66705711,
#        23.7241169 , 16.25656196, 35.07230826, 30.61313659, 24.97909336,
#        24.38275703, 21.14295965, 19.1314371 , 23.16338274, 23.6618131 ,
#        15.19739743, 25.34401559, 29.18014929, 16.23876088, 10.3020992 ,
#        27.29323434, 25.219408  , 21.21416399, 24.14244238, 28.53040971,
#        23.40369738, 21.78379869, 16.19425816, 29.89219267, 20.92044609,
#        18.44609535, 20.80473904, 16.75499233, 22.82516213, 21.50788188,
#        26.52778771, 25.62883294, 23.37699575, 14.96598333, 17.63614601,
#        21.86390357, 22.21992526, 26.54558879, 28.75292327, 20.63562874,
#        18.23248234, 24.34715486, 21.91730682, 23.25238816, 27.84506796,
#        17.51153842, 33.00738246, 27.72936091, 24.65867383, 24.10684022,
#        22.84296322, 15.20629798, 21.0272526 , 34.70738602, 21.32987104,
#        20.3953141 , 24.95239173, 19.75447506, 21.55238459, 19.03353114,
#        23.56390714, 28.94873519, 19.22044253, 24.85448576, 23.90212774,
#        11.48587132, 26.74140072, 30.61313659, 13.87121664, 21.51678242,
#        26.06495951, 26.81260506, 23.0298746 , 26.45658337, 23.77752015,
#        25.18380583, 19.68327072, 21.0272526 , 18.97122734, 15.22409906,
#        20.9649488 , 40.51053956, 25.91365029, 17.90316227, 29.09114387,
#        32.66916185, 23.67071365, 18.76651487, 22.43353827, 18.161278  ,
#        23.96443154, 17.47593625, 26.64349475, 10.83613174, 33.59481824,
#        20.19060163, 18.65080782, 31.11156696, 19.40735391, 23.8932272 ,
#        20.23510434, 19.30054741, 18.13457637, 16.74609178, 27.02621807,
#        24.9256901 , 36.26498092, 19.49635934, 21.1963629 , 10.50681167,
#        24.47176245, 17.45813516, 21.92620737, 17.51153842, 19.29164686,
#        29.9188943 , 18.99792897, 21.63248947, 17.90316227, 15.79373376,
#        26.91941156, 26.54558879])

# %%
y_pred_slr = slr.predict(X_test)
y_pred_slr
# Out:
# array([19.54976259, 18.31258722, 19.15813873, 41.20478186, 23.77752015,
#        16.65708636, 21.55238459, 24.63197221, 23.60840985, 21.50788188,
#        25.45972264, 21.1963629 , 17.4670357 , 27.40004084, 19.63876801,
#        30.16810948, 19.14033765, -1.64242849, 17.24452215, 19.78117669,
#         8.0680631 , 17.94766499, 13.58639929, 30.5508328 , 21.40997592,
#        17.92096336, 16.78169395, 20.98274989, 17.67174818, 27.66705711,
#        23.7241169 , 16.25656196, 35.07230826, 30.61313659, 24.97909336,
#        24.38275703, 21.14295965, 19.1314371 , 23.16338274, 23.6618131 ,
#        15.19739743, 25.34401559, 29.18014929, 16.23876088, 10.3020992 ,
#        27.29323434, 25.219408  , 21.21416399, 24.14244238, 28.53040971,
#        23.40369738, 21.78379869, 16.19425816, 29.89219267, 20.92044609,
#        18.44609535, 20.80473904, 16.75499233, 22.82516213, 21.50788188,
#        26.52778771, 25.62883294, 23.37699575, 14.96598333, 17.63614601,
#        21.86390357, 22.21992526, 26.54558879, 28.75292327, 20.63562874,
#        18.23248234, 24.34715486, 21.91730682, 23.25238816, 27.84506796,
#        17.51153842, 33.00738246, 27.72936091, 24.65867383, 24.10684022,
#        22.84296322, 15.20629798, 21.0272526 , 34.70738602, 21.32987104,
#        20.3953141 , 24.95239173, 19.75447506, 21.55238459, 19.03353114,
#        23.56390714, 28.94873519, 19.22044253, 24.85448576, 23.90212774,
#        11.48587132, 26.74140072, 30.61313659, 13.87121664, 21.51678242,
#        26.06495951, 26.81260506, 23.0298746 , 26.45658337, 23.77752015,
#        25.18380583, 19.68327072, 21.0272526 , 18.97122734, 15.22409906,
#        20.9649488 , 40.51053956, 25.91365029, 17.90316227, 29.09114387,
#        32.66916185, 23.67071365, 18.76651487, 22.43353827, 18.161278  ,
#        23.96443154, 17.47593625, 26.64349475, 10.83613174, 33.59481824,
#        20.19060163, 18.65080782, 31.11156696, 19.40735391, 23.8932272 ,
#        20.23510434, 19.30054741, 18.13457637, 16.74609178, 27.02621807,
#        24.9256901 , 36.26498092, 19.49635934, 21.1963629 , 10.50681167,
#        24.47176245, 17.45813516, 21.92620737, 17.51153842, 19.29164686,
#        29.9188943 , 18.99792897, 21.63248947, 17.90316227, 15.79373376,
#        26.91941156, 26.54558879])

# %%
X_mlr = df[['rm', 'lstat', 'ptratio']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_mlr, y, test_size=0.3, random_state=42)

# %%
mlr = LinearRegression()
mlr.fit(X_train, y_train)
y_pred_mlr = mlr.predict(X_test)
y_pred_mlr
# Out:
# array([26.92298627, 30.93686434, 16.47934188, 25.25409179, 18.28052198,
#        22.71776451, 17.48030837, 12.67868396, 20.65299142, 19.72674849,
#        19.62053908, 21.39117368, -1.63888554, 22.28305258, 19.5334365 ,
#        24.73953404, 17.1762308 ,  3.83959545, 39.02235903, 17.25781087,
#        25.90189855, 27.47962656, 11.74316928, 23.53277967, 17.93698432,
#        13.86981688, 22.65619649, 19.32774678, 18.15760126, 18.82706414,
#        19.72132643, 25.49788496, 25.14274849, 18.4146037 , 14.50579644,
#        21.30312278, 32.36532273, 20.91382657, 20.20888187, 24.82872147,
#        12.74319123, 28.21994868, 39.52761971, 18.8078418 , 26.03183697,
#        15.77223641, 14.27426728, 26.09480414, 18.29649761, 31.22324968,
#        23.74269632, 33.559009  , 16.01682884, 25.67415581, 38.30791834,
#        22.41596988, 18.34605716, 30.13739458, 24.81027677, 15.41857328,
#        25.51195584, 32.09021934, 30.05047579, 17.23144792, 28.34222612,
#        11.86980665, 19.1480674 , 25.75429805, 29.12514764, 15.79015904,
#        19.88273951, 26.09730807, 12.33888366, 22.23200188, 23.1314535 ,
#         6.41435164, 20.10073845, 38.1544859 , 17.06995372, 10.35259168,
#        22.72121997,  9.6942068 , 24.55857764,  7.53987011, 21.98649711,
#        28.2178352 , 20.59994638, 26.10560908, 26.34877021, 19.74793474,
#        24.50546188,  8.15176187, 20.59383612, 20.50588955, 12.24623581,
#        21.49236192, 22.62621129,  0.4347032 , 18.53787164, 17.48451483,
#        21.17122265, 24.59169039,  9.20386137, 20.87618555, 25.68225041,
#        13.75390353, 18.68989006, 26.80947109, 22.75196824, 28.16036995,
#        12.0507692 , 19.2302679 , 24.73626113, 24.42459707, 31.19533926,
#        19.16055227, 32.80629629, 14.93817743, 19.70993618, 28.84283396,
#        18.98960777, 26.99209141, 14.72626665, 23.35888957, 26.66351327,
#        23.47608396, 27.87721499, 31.75103545, 23.74789859, 37.86507884,
#        10.10254627, 27.32765496, 19.15880702, 19.54632651, 11.34957288,
#        22.03831612, 22.54604901, 33.09747695, 31.45865548, 16.51591738,
#        17.80166919, 30.63460947, 23.81829578, 11.59625071,  8.71451997,
#        23.85461499, 23.58446619, 17.39850171, 13.84349989, 39.21649855,
#        19.5392455 , 18.58005169])

# %%
print("\nMLR Results")
print("R2:", r2_score(y_test, y_pred_mlr))
# Out:
# MLR Results
# R2: 0.650904156861472

# %%
coef_df = pd.DataFrame({
    "Feature": X_mlr.columns,
    "Coefficient": mlr.coef_
})
print(coef_df)
# Out:
#    Feature  Coefficient
# 0       rm     4.461626
# 1    lstat    -0.608150
# 2  ptratio    -0.862905

# %%
pred_df = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred_mlr
})

pred_df.head()
# Out:
#    Actual  Predicted
# 0    23.6  26.922986
# 1    32.4  30.936864
# 2    13.6  16.479342
# 3    22.8  25.254092
# 4    16.1  18.280522

# %%
ols_model = smf.ols(formula="medv ~ rm + lstat + ptratio",data=df).fit()
print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   medv   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     353.3
# Date:                Tue, 01 Sep 2026   Prob (F-statistic):          2.69e-123
# Time:                        04:36:55   Log-Likelihood:                -1553.0
# No. Observations:                 506   AIC:                             3114.
# Df Residuals:                     502   BIC:                             3131.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     18.5671      3.913      4.745      0.000      10.879      26.255
# rm             4.5154      0.426     10.603      0.000       3.679       5.352
# lstat         -0.5718      0.042    -13.540      0.000      -0.655      -0.489
# ptratio       -0.9307      0.118     -7.911      0.000      -1.162      -0.700
# ==============================================================================
# Omnibus:                      202.072   Durbin-Watson:                   0.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1022.153
# Skew:                           1.700   Prob(JB):                    1.10e-222
# Kurtosis:                       9.076   Cond. No.                         402.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm
# Select 4 independent variables
X = df[['rm', 'lstat', 'ptratio', 'crim']]
y = df['medv']
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   medv   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     268.0
# Date:                Tue, 01 Sep 2026   Prob (F-statistic):          5.84e-123
# Time:                        04:50:13   Log-Likelihood:                -1550.8
# No. Observations:                 506   AIC:                             3112.
# Df Residuals:                     501   BIC:                             3133.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         16.9233      3.976      4.257      0.000       9.112      24.734
# rm             4.6186      0.427     10.812      0.000       3.779       5.458
# lstat         -0.5343      0.046    -11.708      0.000      -0.624      -0.445
# ptratio       -0.8897      0.119     -7.487      0.000      -1.123      -0.656
# crim          -0.0654      0.031     -2.124      0.034      -0.126      -0.005
# ==============================================================================
# Omnibus:                      219.815   Durbin-Watson:                   0.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1220.115
# Skew:                           1.840   Prob(JB):                    1.14e-265
# Kurtosis:                       9.658   Cond. No.                         417.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ols_model = smf.ols(
    formula="medv ~ rm + lstat + ptratio + crim",
    data=df
).fit()

print(ols_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   medv   R-squared:                       0.681
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     268.0
# Date:                Tue, 01 Sep 2026   Prob (F-statistic):          5.84e-123
# Time:                        04:50:47   Log-Likelihood:                -1550.8
# No. Observations:                 506   AIC:                             3112.
# Df Residuals:                     501   BIC:                             3133.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     16.9233      3.976      4.257      0.000       9.112      24.734
# rm             4.6186      0.427     10.812      0.000       3.779       5.458
# lstat         -0.5343      0.046    -11.708      0.000      -0.624      -0.445
# ptratio       -0.8897      0.119     -7.487      0.000      -1.123      -0.656
# crim          -0.0654      0.031     -2.124      0.034      -0.126      -0.005
# ==============================================================================
# Omnibus:                      219.815   Durbin-Watson:                   0.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1220.115
# Skew:                           1.840   Prob(JB):                    1.14e-265
# Kurtosis:                       9.658   Cond. No.                         417.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
